# %% [markdown]
# # 动态血糖预测模型测试

# %%
# 导入相关函数包
import torch
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
filename = "Datasets/DynamicBloodGlucoseData.csv"
with open(filename, encoding='utf-8') as f:
    data = np.loadtxt(f,delimiter=",",skiprows=1)

# %%
data.shape
# Out:
# (4793, 3)

# %%
plt.scatter(data[:,2], data[:,1],s=1)
plt.show()

# %%
type(data)
# Out:
# numpy.ndarray
